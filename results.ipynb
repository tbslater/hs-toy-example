# %%
from plot import Plot

# %% [markdown]
# #### SCENARIO 1: NO POLICIES IMPLEMENTED

# %%
scenario_1 = Plot()
scenario_1.plot_users('sce1-users.png')
scenario_1.plot_weekly_visits('sce1-visits.png')
# Out:
# Iteration 1 complete.
# Iteration 2 complete.
# Iteration 3 complete.
# Iteration 4 complete.
# Iteration 5 complete.
# Iteration 6 complete.
# Iteration 7 complete.
# Iteration 8 complete.
# Iteration 9 complete.
# Iteration 10 complete.

# %% [markdown]
# #### SCENARIO 2: WEEKLY SESSION FOR THE LEAST ACTIVE GIRLS

# %%
scenario_2 = Plot(weekly_session = True)
scenario_2.plot_users('sce2-users.png')
scenario_2.plot_weekly_visits('sce2-visits.png')
# Out:
# Iteration 1 complete.
# Iteration 2 complete.
# Iteration 3 complete.
# Iteration 4 complete.
# Iteration 5 complete.
# Iteration 6 complete.
# Iteration 7 complete.
# Iteration 8 complete.
# Iteration 9 complete.
# Iteration 10 complete.

# %% [markdown]
# #### SCENARIO 3: UPGRADE TO THE PARK

# %%
scenario_3 = Plot(upgrade = True)
scenario_3.plot_users('sce3-users.png')
scenario_3.plot_weekly_visits('sce3-visits.png')
# Out:
# Iteration 1 complete.
# Iteration 2 complete.
# Iteration 3 complete.
# Iteration 4 complete.
# Iteration 5 complete.
# Iteration 6 complete.
# Iteration 7 complete.
# Iteration 8 complete.
# Iteration 9 complete.
# Iteration 10 complete.

# %% [markdown]
# #### SCENARIO 4: PARK UPGRADE + INCREASED MAINTENANCE

# %%
scenario_4 = Plot(upgrade = True, maintenance = True)
scenario_4.plot_users('sce4-users.png')
scenario_4.plot_weekly_visits('sce4-visits.png')
# Out:
# Iteration 1 complete.
# Iteration 2 complete.
# Iteration 3 complete.
# Iteration 4 complete.
# Iteration 5 complete.
# Iteration 6 complete.
# Iteration 7 complete.
# Iteration 8 complete.
# Iteration 9 complete.
# Iteration 10 complete.

# %% [markdown]
# #### SCENARIO 5: PARK UPGRADE + WEEKLY SESSION

# %%
scenario_5 = Plot(upgrade = True, weekly_session = True)
scenario_5.plot_users('sce5-users.png')
scenario_5.plot_weekly_visits('sce5-visits.png')
# Out:
# Iteration 1 complete.
# Iteration 2 complete.
# Iteration 3 complete.
# Iteration 4 complete.
# Iteration 5 complete.
# Iteration 6 complete.
# Iteration 7 complete.
# Iteration 8 complete.
# Iteration 9 complete.
# Iteration 10 complete.

# %% [markdown]
# #### SCENARIO 6: PARK UPGRADE + INCREASED MAINTENANCE + WEEKLY SESSION

# %%
scenario_6 = Plot(upgrade = True, maintenance = True, weekly_session = True)
scenario_6.plot_users('sce6-users.png')
scenario_6.plot_weekly_visits('sce6-visits.png')
# Out:
# Iteration 1 complete.
# Iteration 2 complete.
# Iteration 3 complete.
# Iteration 4 complete.
# Iteration 5 complete.
# Iteration 6 complete.
# Iteration 7 complete.
# Iteration 8 complete.
# Iteration 9 complete.
# Iteration 10 complete.
